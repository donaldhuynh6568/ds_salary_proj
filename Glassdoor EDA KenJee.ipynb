# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df = pd.read_csv('salary_data_cleaned.csv')

# %%
df.head()
# Out:
#                    Job Title              Salary Estimate  \
# 0             Data Scientist   $53K-$91K (Glassdoor est.)
# 1  Healthcare Data Scientist  $63K-$112K (Glassdoor est.)
# 2             Data Scientist   $80K-$90K (Glassdoor est.)
# 3             Data Scientist   $56K-$97K (Glassdoor est.)
# 4             Data Scientist  $86K-$143K (Glassdoor est.)
#
#                                      Job Description  Rating  \
# 0  Data Scientist\nLocation: Albuquerque, NM\nEdu...     3.8
# 1  What You Will Do:\n\nI. General Summary\n\nThe...     3.4
# 2  KnowBe4, Inc. is a high growth information sec...     4.8
# 3  *Organization and Job ID**\nJob ID: 310709\n\n...     3.8
# 4  Data Scientist\nAffinity Solutions / Marketing...     2.9
#
#                                  Company Name         Location  \
# 0                      Tecolote Research\n3.8  Albuquerque, NM
# 1  University of Maryland Medical System\n3.4    Linthicum, MD
# ...

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_text', 'job_state', 'same_state', 'age', 'python', 'Tableau',
#        'AWS', 'Excel', 'SQL', 'R_yn'],
#       dtype='object')

# %%
def title_simplifier(title):
    if 'data scientist' in title.lower():
        return 'data scientist'
    elif 'data engineer' in title.lower():
        return 'data engineer'
    elif 'analyst' in title.lower():
        return 'analyst'
    elif 'machine learning' in title.lower():
        return 'mle'
    elif 'manager' in title.lower():
        return 'manager'
    elif 'director' in title.lower():
        return 'director'
    else:
        return 'na'
    
def seniority(title):
    if 'sr' in title.lower() or 'sr.' in title.lower() or 'senior' in title.lower() or 'lead' in title.lower() or 'principal' in title.lower():
        return 'senior'
    elif 'jr' in title.lower() or 'jr.' in title.lower():
        return 'jr'
    else:
        return 'na'

# %%
#job title and seniority

df['job_simp']= df['Job Title'].apply(title_simplifier)

# %%
df.job_simp.value_counts()
# Out:
# data scientist    279
# na                184
# data engineer     119
# analyst           102
# mle                22
# manager            22
# director           14
# Name: job_simp, dtype: int64

# %%
df['seniority']= df['Job Title'].apply(seniority)
df.seniority.value_counts()
# Out:
# na        520
# senior    220
# jr          2
# Name: seniority, dtype: int64

# %%
#fix state Los Angeles
#strip() removes any extra spaces
#df.drop(column, inplace=True/False, axis=1) if you want to drop a column
df.job_state.value_counts()
df['job_state']= df.job_state.apply(lambda x: x.strip() if x.strip().lower() != 'los angeles' else 'CA')
df.job_state.value_counts()
# Out:
# CA    152
# MA    103
# NY     72
# VA     41
# IL     40
# MD     35
# PA     33
# TX     28
# WA     21
# NC     21
# NJ     17
# FL     16
# OH     14
# TN     13
# CO     11
# DC     11
# IN     10
# UT     10
# WI     10
# MO      9
# AZ      9
# AL      8
# GA      6
# DE      6
# MI      6
# KY      6
# IA      5
# CT      5
# LA      4
# OR      4
# NE      4
# KS      3
# NM      3
# MN      2
# ID      2
# SC      1
# RI      1
# Name: job_state, dtype: int64

# %%
# Job description length
# Description length can be an indicator for higher or lower salary

df['desc_len']=df['Job Description'].apply(lambda x: len(x))
df['desc_len']
# Out:
# 0      2536
# 1      4783
# 2      3461
# 3      3883
# 4      2728
#        ...
# 737    6162
# 738    6130
# 739    3078
# 740    1642
# 741    3673
# Name: desc_len, Length: 742, dtype: int64

# %%
#split() splits it into a list. so split(',') would split the data into a list of data on the comma

# %%
# Hourly wage to annual

df['min_salary'] = df.apply(lambda x: x.min_salary*2 if x.hourly == 1 else x.min_salary, axis=1)
df['max_salary'] = df.apply(lambda x: x.max_salary*2 if x.hourly == 1 else x.max_salary, axis=1)

# %%
df[df.hourly ==1][['hourly','min_salary','max_salary']]
# Out:
#      hourly  min_salary  max_salary
# 165       1          34          48
# 177       1          42          68
# 197       1          36          50
# 202       1          42          68
# 210       1          30          50
# 246       1          34          48
# 271       1          42          68
# 337       1          36          50
# 345       1          48          78
# 357       1          42          68
# 363       1          50          56
# 408       1          42          58
# 409       1          20          34
# 492       1          36          50
# 509       1          48          78
# 533       1          42          68
# 542       1          50          56
# 617       1          42          58
# 618       1          20          34
# 645       1          54          94
# 666       1          36          50
# 682       1          48          78
# 711       1          42          68
# 724       1          50          56

# %%
#remove newline character from job title
df['company_text']= df.company_text.apply(lambda x: x.replace('\n', ''))
df['company_text']
# Out:
# 0                          Tecolote Research
# 1      University of Maryland Medical System
# 2                                    KnowBe4
# 3                                       PNNL
# 4                         Affinity Solutions
#                        ...
# 737                                      GSK
# 738                               Eventbrite
# 739           Software Engineering Institute
# 740                             Numeric, LLC
# 741             Riverside Research Institute
# Name: company_text, Length: 742, dtype: object

# %%
df.describe()
# Out:
#            Rating      Founded      hourly  employer_provided  min_salary  \
# count  742.000000   742.000000  742.000000         742.000000  742.000000
# mean     3.618868  1837.154987    0.032345           0.022911   74.719677
# std      0.801210   497.183763    0.177034           0.149721   30.980593
# min     -1.000000    -1.000000    0.000000           0.000000   15.000000
# 25%      3.300000  1939.000000    0.000000           0.000000   52.000000
# 50%      3.700000  1988.000000    0.000000           0.000000   69.500000
# 75%      4.000000  2007.000000    0.000000           0.000000   91.000000
# max      5.000000  2019.000000    1.000000           1.000000  202.000000
#
#        max_salary  avg_salary  same_state         age      python     Tableau  \
# count  742.000000  742.000000  742.000000  742.000000  742.000000  742.000000
# mean   128.149596  100.626011    0.557951   47.524259    0.528302    0.199461
# ...

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_text', 'job_state', 'same_state', 'age', 'python', 'Tableau',
#        'AWS', 'Excel', 'SQL', 'R_yn', 'job_simp', 'seniority', 'desc_len'],
#       dtype='object')

# %%
#make histograms to see how data is distributed
df.Rating.hist()

# %%
df.avg_salary.hist()

# %%
df.age.hist()
#would need to normalize this because exponential

# %%
df.desc_len.hist()

# %%
df.boxplot(column= ['age', 'avg_salary', 'Rating'])

# %%
df.boxplot(column= 'Rating')

# %%
#next thing we want to do is look at correlation of our continous variables
df[['age', 'avg_salary', 'Rating', 'desc_len']].corr()
# Out:
#                  age  avg_salary    Rating  desc_len
# age         1.000000    0.019574  0.023162  0.164188
# avg_salary  0.019574    1.000000  0.013492  0.078808
# Rating      0.023162    0.013492  1.000000 -0.012281
# desc_len    0.164188    0.078808 -0.012281  1.000000

# %%
cmap = sns.diverging_palette(230, 20, as_cmap=True)

sns.heatmap(df[['age', 'avg_salary', 'Rating', 'desc_len']].corr(), cmap=cmap, vmax=.3, center=0,
            square=True, linewidths=.5, cbar_kws={"shrink": .5})

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_text', 'job_state', 'same_state', 'age', 'python', 'Tableau',
#        'AWS', 'Excel', 'SQL', 'R_yn', 'job_simp', 'seniority', 'desc_len'],
#       dtype='object')

# %%
# go into categorical variables

df_cat=df[['Location', 'Headquarters', 'Size','company_text','Company Name','Type of ownership', 'Industry', 'Sector', 'Revenue','Company Name', 'job_state','same_state','python', 'Tableau',
       'AWS', 'Excel', 'SQL', 'R_yn', 'job_simp', 'seniority', 'desc_len']]

# %%
for i in df_cat.columns:
    cat_num= df_cat[i].value_counts()
    print('Graph for %s: total= %d' % (i, len(cat_num)))
    chart=sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# Graph for Location: total= 200
# Graph for Headquarters: total= 198
# Graph for Size: total= 9
# Graph for Type of ownership: total= 11
# Graph for Industry: total= 60
# Graph for Sector: total= 25
# Graph for Revenue: total= 14
# Graph for Company Name: total= 343
# Graph for job_state: total= 37
# Graph for same_state: total= 2
# Graph for python: total= 2
# Graph for Tableau: total= 2
# Graph for AWS: total= 2
# Graph for Excel: total= 2
# Graph for SQL: total= 2
# Graph for R_yn: total= 2
# Graph for job_simp: total= 7
# Graph for seniority: total= 3
# Graph for desc_len: total= 443

# %%
for i in df_cat[['Location','Headquarters','company_text']].columns:
    cat_num= df_cat[i].value_counts()[:20]
    print('Graph for %s: total= %d' % (i, len(cat_num)))
    chart=sns.barplot(x=cat_num.index, y=cat_num)
    chart.set_xticklabels(chart.get_xticklabels(), rotation=90)
    plt.show()
# Out:
# Graph for Location: total= 20
# Graph for Headquarters: total= 20
# Graph for company_text: total= 20

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_text', 'job_state', 'same_state', 'age', 'python', 'Tableau',
#        'AWS', 'Excel', 'SQL', 'R_yn', 'job_simp', 'seniority', 'desc_len'],
#       dtype='object')

# %%
pd.pivot_table(df, index= 'job_simp', values= 'avg_salary')
# Out:
#                 avg_salary
# job_simp
# analyst          65.857843
# data engineer   105.403361
# data scientist  117.564516
# director        168.607143
# manager          84.022727
# mle             126.431818
# na               84.853261

# %%
pd.pivot_table(df, index= ['job_simp','seniority'], values= 'avg_salary')
# Out:
#                           avg_salary
# job_simp       seniority
# analyst        jr          56.500000
#                na          61.155405
#                senior      79.092593
# data engineer  na          96.701220
#                senior     124.689189
# data scientist jr         106.500000
#                na         107.043011
#                senior     138.956522
# director       na         168.607143
# manager        na          84.022727
# mle            na         119.133333
#                senior     142.071429
# na             na          73.988189
#                senior     109.061404

# %%
pd.pivot_table(df, index= ['job_state','job_simp'], values= 'avg_salary', aggfunc='count').sort_values('job_state', ascending= False)
# Out:
#                           avg_salary
# job_state job_simp
# WI        na                       4
#           data scientist           3
#           analyst                  3
# WA        na                       1
#           data scientist          17
#           analyst                  3
# VA        na                       5
#           mle                      2
#           data scientist          18
#           data engineer           10
#           analyst                  6
# UT        data engineer            3
#           analyst                  4
#           data scientist           3
# TX        na                       7
#           data scientist          13
#           data engineer            8
# TN        data scientist           1
#           data engineer           10
#           analyst                  2
# SC        na                       1
# RI        analyst                  1
# PA        manager                  3
#           data engineer            1
# ...

# %%
pd.options.display.max_rows
# Out:
# 60

# %%
pd.set_option('display.max_rows', None)

# %%
pd.pivot_table(df[df.job_simp =='data scientist'], index='job_state', values= 'avg_salary').sort_values('avg_salary', ascending= False)
# Out:
#            avg_salary
# job_state
# DC         149.000000
# CA         142.522059
# UT         140.500000
# MO         127.666667
# IL         117.233333
# NC         117.000000
# NY         115.250000
# MA         113.750000
# WI         113.500000
# PA         113.333333
# MD         109.115385
# CO         108.666667
# VA         108.416667
# NJ         106.875000
# MI         106.625000
# OH         105.285714
# TX         100.730769
# WA          99.764706
# OR          98.500000
# FL          97.357143
# TN          96.000000
# IN          84.500000
# KY          84.000000
# CT          84.000000
# GA          81.333333
# NM          74.333333
# AZ          69.500000

# %%
df.columns
# Out:
# Index(['Job Title', 'Salary Estimate', 'Job Description', 'Rating',
#        'Company Name', 'Location', 'Headquarters', 'Size', 'Founded',
#        'Type of ownership', 'Industry', 'Sector', 'Revenue', 'Competitors',
#        'hourly', 'employer_provided', 'min_salary', 'max_salary', 'avg_salary',
#        'company_text', 'job_state', 'same_state', 'age', 'python', 'Tableau',
#        'AWS', 'Excel', 'SQL', 'R_yn', 'job_simp', 'seniority', 'desc_len'],
#       dtype='object')

# %%
# rating, industry, sector, revenue, number of comp, hourly, employer provided, python, tableau, aws, excel, SQL, desc_len, type of ownership
#will go through and make pivot tables for interesting insights
